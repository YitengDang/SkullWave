# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# Plot GFP intensity profiles across medial-lateral axis of fixed tissue images and live imaging movies.

# %%
import numpy as np
# from scipy import stats
# from scipy import optimize
import matplotlib.pyplot as plt
#import matplotlib.image as mpimg
import pandas as pd
import os
import seaborn as sns
cwd = os.getcwd(); print("Working dir: " + cwd)
# Out:
# Working dir: /Users/dang/Documents/Projects/Tabler_skull/Scripts/Scripts_python

# %%
# Make plots interactive
# %matplotlib notebook

# Make plots static 
# %matplotlib inline

# %%
## Load WT data
folder = "/Users/dang/Documents/Projects/Tabler_skull/Data_skull_expansion/cropped_fronts_OsxGFP_SD4/Ctrl/"
# get a list of files
import glob
files = glob.glob( os.path.join(folder, "*.csv") )
print(files)

loaded_data = [None for i in range(len(files))]

for i, file in enumerate(files):
    loaded_data[i] = pd.read_csv(file)
# Out:
# ['/Users/dang/Documents/Projects/Tabler_skull/Data_skull_expansion/cropped_fronts_OsxGFP_SD4/Ctrl/MAX_Stitched_2022_06_14_e13,75_Ctl_OsxCreGFP_DAPI_#6left_very_thin_profile.csv', '/Users/dang/Documents/Projects/Tabler_skull/Data_skull_expansion/cropped_fronts_OsxGFP_SD4/Ctrl/MAX_stitched_2022_06_14_e13,75_Ctl_OsxCreGFP_DAPI_#3right_ds2_noIP_profile.csv', '/Users/dang/Documents/Projects/Tabler_skull/Data_skull_expansion/cropped_fronts_OsxGFP_SD4/Ctrl/MAX_stitched_2022_06_14_e13,75_Ctl_OsxCreGFP_DAPI_#2right_no_IP_slice_profile.csv', '/Users/dang/Documents/Projects/Tabler_skull/Data_skull_expansion/cropped_fronts_OsxGFP_SD4/Ctrl/MAX_Stitched_2022_06_14_e13,75_Ctl_OsxCreGFP_DAPI_#1right_crop2_plot_profile.csv', '/Users/dang/Documents/Projects/Tabler_skull/Data_skull_expansion/cropped_fronts_OsxGFP_SD4/Ctrl/MAX_stitched_2022_06_14_e13,75_Ctl_OsxCreGFP_DAPI_#4right_20220616_135209_profile.csv', '/Users/dang/Documents/Projects/Tabler_skull/Data_skull_expansion/cropped_fronts_OsxGFP_SD4/Ctr
# ...

# %%
## Load BAPN data
folder = "/Users/dang/Documents/Projects/Tabler_skull/Data_skull_expansion/cropped_fronts_OsxGFP_SD4/BAPN/"
# get a list of files
import glob
files_bapn = glob.glob( os.path.join(folder, "*.csv") )
print(files)

loaded_data_bapn = [None for i in range(len(files_bapn))]


for i, file in enumerate(files_bapn):
    loaded_data_bapn[i] = pd.read_csv(file)
    
# loaded_data_bapn[8]['Gray_Value']=loaded_data_bapn[8]['Gray_Value']*256 # convert intensity vaules

# loaded_data_bapn
# Out:
# ['/Users/dang/Documents/Projects/Tabler_skull/Data_skull_expansion/cropped_fronts_OsxGFP_SD4/Ctrl/MAX_Stitched_2022_06_14_e13,75_Ctl_OsxCreGFP_DAPI_#6left_very_thin_profile.csv', '/Users/dang/Documents/Projects/Tabler_skull/Data_skull_expansion/cropped_fronts_OsxGFP_SD4/Ctrl/MAX_stitched_2022_06_14_e13,75_Ctl_OsxCreGFP_DAPI_#3right_ds2_noIP_profile.csv', '/Users/dang/Documents/Projects/Tabler_skull/Data_skull_expansion/cropped_fronts_OsxGFP_SD4/Ctrl/MAX_stitched_2022_06_14_e13,75_Ctl_OsxCreGFP_DAPI_#2right_no_IP_slice_profile.csv', '/Users/dang/Documents/Projects/Tabler_skull/Data_skull_expansion/cropped_fronts_OsxGFP_SD4/Ctrl/MAX_Stitched_2022_06_14_e13,75_Ctl_OsxCreGFP_DAPI_#1right_crop2_plot_profile.csv', '/Users/dang/Documents/Projects/Tabler_skull/Data_skull_expansion/cropped_fronts_OsxGFP_SD4/Ctrl/MAX_stitched_2022_06_14_e13,75_Ctl_OsxCreGFP_DAPI_#4right_20220616_135209_profile.csv', '/Users/dang/Documents/Projects/Tabler_skull/Data_skull_expansion/cropped_fronts_OsxGFP_SD4/Ctr
# ...

# %%
fig, ax = plt.subplots(dpi=100);
for i, plot_data in enumerate(loaded_data):
    #print(i)
    #sns.lineplot(data=plot_data, x="Distance_(µm)", y="Gray_Value", ax=ax)
    sns.lineplot(data=plot_data, x=plot_data.columns[0], y=plot_data.columns[1], ax=ax, label=i)
plt.legend()
plt.show()

fig, ax = plt.subplots(dpi=100);
for i, plot_data in enumerate(loaded_data_bapn):
    #print(i)
    #sns.lineplot(data=plot_data, x="Distance_(µm)", y="Gray_Value", ax=ax)
    sns.lineplot(data=plot_data, x=plot_data.columns[0], y=plot_data.columns[1], ax=ax, label=i)

plt.legend()
plt.show()

# %%
i=0
plot_data = loaded_data_bapn[i]
sns.lineplot(data=plot_data, x=plot_data.columns[0], y=plot_data.columns[1])
# Out:
# <AxesSubplot:xlabel='Distance_(pixels)', ylabel='Gray_Value'>

# %%
plot_data = loaded_data_bapn[i]
sns.lineplot(data=plot_data, x='Distance2', y=plot_data.columns[1])
# Out:
# <AxesSubplot:xlabel='Distance2', ylabel='Gray_Value'>

# %%
# Try to obtain the same origin by eye
# BAPN
plot_data_all = loaded_data_bapn.copy()
i=0; offset=450;
plot_data_all[i]['Distance2'] = (plot_data_all[i][plot_data_all[i].columns[0]].values) - offset
i=1; offset=1500;
plot_data_all[i]['Distance2'] = (plot_data_all[i][plot_data_all[i].columns[0]].values) - offset
i=2; offset=800;
plot_data_all[i]['Distance2'] = (plot_data_all[i][plot_data_all[i].columns[0]].values) - offset
i=3; offset=850;
plot_data_all[i]['Distance2'] = (plot_data_all[i][plot_data_all[i].columns[0]].values) - offset
i=4; offset=800;
plot_data_all[i]['Distance2'] = (plot_data_all[i][plot_data_all[i].columns[0]].values) - offset
i=5; offset=1150;
plot_data_all[i]['Distance2'] = (plot_data_all[i][plot_data_all[i].columns[0]].values) - offset
i=6; offset=950;
plot_data_all[i]['Distance2'] = (plot_data_all[i][plot_data_all[i].columns[0]].values) - offset
i=7; offset=500;
plot_data_all[i]['Distance2'] = (plot_data_all[i][plot_data_all[i].columns[0]].values) - offset
i=8; offset=400;
plot_data_all[i]['Distance2'] = (plot_data_all[i][plot_data_all[i].columns[0]].values) - offset
i=9; offset=800;
plot_data_all[i]['Distance2'] = (plot_data_all[i][plot_data_all[i].columns[0]].values) - offset
plot_data_all_bapn = plot_data_all.copy();

# %%
# Try to obtain the same origin by eye
# WT
plot_data_all = loaded_data.copy()
i=0; offset=220;
plot_data_all[i]['Distance2'] = (plot_data_all[i][plot_data_all[i].columns[0]].values) - offset
i=1; offset=320;
plot_data_all[i]['Distance2'] = (plot_data_all[i][plot_data_all[i].columns[0]].values) - offset
i=2; offset=620;
plot_data_all[i]['Distance2'] = (plot_data_all[i][plot_data_all[i].columns[0]].values) - offset
i=3; offset=750;
plot_data_all[i]['Distance2'] = (plot_data_all[i][plot_data_all[i].columns[0]].values) - offset
i=4; offset=500;
plot_data_all[i]['Distance2'] = (plot_data_all[i][plot_data_all[i].columns[0]].values) - offset
i=5; offset=700;
plot_data_all[i]['Distance2'] = (plot_data_all[i][plot_data_all[i].columns[0]].values) - offset
i=6; offset=480;
plot_data_all[i]['Distance2'] = (plot_data_all[i][plot_data_all[i].columns[0]].values) - offset
i=7; offset=340;
plot_data_all[i]['Distance2'] = (plot_data_all[i][plot_data_all[i].columns[0]].values) - offset
i=8; offset=360;
plot_data_all[i]['Distance2'] = (plot_data_all[i][plot_data_all[i].columns[0]].values) - offset

# %%
fig, ax = plt.subplots(dpi=100);
for i, plot_data in enumerate(loaded_data):
    #print(i)
    #sns.lineplot(data=plot_data, x="Distance_(µm)", y="Gray_Value", ax=ax)
    sns.lineplot(data=plot_data, x="Distance2", y=plot_data.columns[1], ax=ax, label=i)    
plt.legend()
plt.show()

fig, ax = plt.subplots(dpi=100);
for i, plot_data in enumerate(loaded_data_bapn):
    #print(i)
    #sns.lineplot(data=plot_data, x="Distance_(µm)", y="Gray_Value", ax=ax)
    sns.lineplot(data=plot_data, x="Distance2", y=plot_data.columns[1], ax=ax, label=i)
plt.legend()   
plt.show()

# %% [markdown]
# Different steepnesses across different images.

# %%
print( files[4] )
print( files[6] )
# Out:
# /Users/dang/Documents/Projects/Tabler_skull/Data_skull_expansion/cropped_fronts_OsxGFP_SD4/Ctrl/MAX_stitched_2022_06_14_e13,75_Ctl_OsxCreGFP_DAPI_#4right_20220616_135209_profile.csv
# /Users/dang/Documents/Projects/Tabler_skull/Data_skull_expansion/cropped_fronts_OsxGFP_SD4/Ctrl/MAX_stitched_2022_06_14_e13,75_Ctl_OsxCreGFP_DAPI_#4left_20220616_140140_fused_profile.csv

# %%
files_bapn[8]
# Out:
# '/Users/dang/Documents/Projects/Tabler_skull/Data_skull_expansion/cropped_fronts_OsxGFP_SD4/BAPN/MAX_Stitched_2022_03_03_BAPN_OsxCreGFP_DAPI_30x_20220303_#4_cut_left.csv'

# %% [markdown]
# These both correspond to image #4, for which we could not get a sufficiently large area of the bone and present a very zoomed in version of the bones.
